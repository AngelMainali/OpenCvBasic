# %%
import pandas as pd

# %%
data={
    'Name':['Alice','Bob','Claire'],
    'Age':[25,30,27],
    'Gender':['Female','Male',None]

}

# %%
df=pd.DataFrame(data,index=['a','b','c'])

# %%
df.head()
# Out:
#      Name  Age  Gender
# a   Alice   25  Female
# b     Bob   30    Male
# c  Claire   27    None

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   27.333333
# std     2.516611
# min    25.000000
# 25%    26.000000
# 50%    27.000000
# 75%    28.500000
# max    30.000000

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Gender    1
# dtype: int64

# %%
mode_value=df['Gender'].mode()[0]

# %%
df=df['Gender'].fillna(mode_value)

# %%
df
# Out:
# a    Female
# b      Male
# c    Female
# Name: Gender, dtype: object

# %%
s1=[99,23,76]

series=pd.Series(s1,index=['s1','s2','s3'],name='marks')

# %%
series
# Out:
# s1    99
# s2    23
# s3    76
# Name: marks, dtype: int64
